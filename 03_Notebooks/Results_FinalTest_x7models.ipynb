# %% [markdown]
# # FINAL TESTs:
#
# *   x2 Dataset: real and synthetic
# *   Only Test images (never seen before)
# *   x7 Modeld (already trained)

# %% [markdown]
# ## Dependencies:

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
from google.colab.patches import cv2_imshow

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
# "DRIVE" forlder acess from Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
drive_maf="/content/drive/MyDrive/..."
#----Change here your Models's PATH!----
ruta_drive=drive_maf

# %% [markdown]
# # Download DATASETS from Roboflow:
#
# There are x2 Dataset:
#
#
# *   REAL
# *   MSFS

# %%
# %cd {HOME}
# !pip install roboflow

# Synthetic: msfs_final
from roboflow import Roboflow
rf = Roboflow(api_key="nbayT1GpNj6CHnws6fWn")
project = rf.workspace("politcnica-de-madrid-gzqnj").project("msfs_final")
dataset = project.version(1).download("yolov8")

# Real: real_final
rf = Roboflow(api_key="nbayT1GpNj6CHnws6fWn")
project = rf.workspace("politcnica-de-madrid-gzqnj").project("real_final")
dataset = project.version(2).download("yolov8")
# Out:
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # FINAL TEST:

# %% [markdown]
# In the Colab file explorer, change the content of **data.yaml** for both datasets so that it points to test (i.e., val: test/images) and save.
#
#
# *   Test Real 139 images
# *   Test MSF 157 images

# %% [markdown]
# ## Real()

# %% [markdown]
# 1) REAL(real_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:13<00:00,  1.52s/it]
#                    all        139        514      0.858      0.822       0.86      0.711
#        Ground_vehicles        139         88      0.877      0.807      0.862      0.784
#        Horizontal_sign        139        106      0.897        0.9      0.936      0.706
# ...

# %% [markdown]
# 2) REAL*(real_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL-A/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:13<00:00,  1.54s/it]
#                    all        139        514      0.852      0.829      0.854       0.71
#        Ground_vehicles        139         88      0.808      0.813       0.86       0.78
#        Horizontal_sign        139        106      0.942      0.913       0.96      0.737
# ...

# %% [markdown]
# 3) REAL**(real_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL-AA/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:13<00:00,  1.49s/it]
#                    all        139        514       0.85      0.844      0.882      0.722
#        Ground_vehicles        139         88      0.845       0.83      0.869      0.777
#        Horizontal_sign        139        106      0.932      0.934      0.972      0.743
# ...

# %% [markdown]
# 4) REAL(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:14<00:00,  1.48s/it]
#                    all        157        571      0.624      0.506      0.526      0.362
#        Ground_vehicles        157        103      0.394     0.0583      0.171      0.124
#        Horizontal_sign        157         89      0.663      0.685      0.713      0.439
# ...

# %% [markdown]
# 5) REAL*(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL-A/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:15<00:00,  1.56s/it]
#                    all        157        571      0.802      0.648      0.699      0.528
#        Ground_vehicles        157        103      0.866      0.485      0.613       0.54
#        Horizontal_sign        157         89      0.922      0.801      0.863      0.613
# ...

# %% [markdown]
# 6) REAL**(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL-AA/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:16<00:00,  1.62s/it]
#                    all        157        571      0.919      0.781       0.85      0.714
#        Ground_vehicles        157        103      0.918      0.766      0.806      0.747
#        Horizontal_sign        157         89          1      0.933      0.991       0.81
# ...

# %% [markdown]
# ## MSFS()

# %% [markdown]
# 7) MSFS(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MSFS/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<00:00, 1638.26it/s]
# val: New cache created: /content/MSFS_Final-1/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:15<00:00,  1.53s/it]
#                    all        157        571      0.869      0.816      0.829      0.666
#        Ground_vehicles        157        103      0.902      0.718      0.781      0.659
# ...

# %% [markdown]
# 8) MSFS*(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MSFS-A/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:14<00:00,  1.47s/it]
#                    all        157        571      0.868      0.795      0.822      0.666
#        Ground_vehicles        157        103       0.87       0.68      0.746      0.648
#        Horizontal_sign        157         89      0.929      0.888      0.937      0.706
# ...

# %% [markdown]
# 9) MSFS**(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MSFS-AA/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:16<00:00,  1.61s/it]
#                    all        157        571      0.881      0.809      0.841      0.674
#        Ground_vehicles        157        103      0.933      0.689      0.765      0.657
#        Horizontal_sign        157         89      0.906      0.876      0.946      0.691
# ...

# %% [markdown]
# 10) MSFS(reat_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MSFS/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:15<00:00,  1.75s/it]
#                    all        139        514      0.618      0.503      0.531       0.35
#        Ground_vehicles        139         88      0.487      0.239       0.23      0.184
#        Horizontal_sign        139        106      0.798      0.764      0.841      0.554
# ...

# %% [markdown]
# 11) MSFS*(reat_test)

# %%
# !yolo task=detect mode=val model={drive_maf}/MSFS-A/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:14<00:00,  1.65s/it]
#                    all        139        514       0.83      0.797      0.829      0.698
#        Ground_vehicles        139         88      0.813      0.705      0.706       0.64
#        Horizontal_sign        139        106      0.915      0.906      0.951      0.778
# ...

# %% [markdown]
# 12) MSFS**(reat_test)

# %%
# !yolo task=detect mode=val model={drive_maf}/MSFS-AA/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:15<00:00,  1.69s/it]
#                    all        139        514      0.948      0.909      0.952      0.841
#        Ground_vehicles        139         88      0.909      0.909      0.947      0.869
#        Horizontal_sign        139        106      0.985      0.972      0.987      0.913
# ...

# %% [markdown]
# ## MIX_50()

# %% [markdown]
# 13) MIX_50(reat_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MIX_50/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<00:00, 1690.69it/s]
# val: New cache created: /content/Real_Final-2/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:13<00:00,  1.48s/it]
#                    all        139        514      0.848       0.76      0.826      0.652
#        Ground_vehicles        139         88      0.849      0.768      0.813      0.707
# ...

# %% [markdown]
# 14) MIX_50(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MIX_50/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<00:00, 1718.51it/s]
# val: New cache created: /content/MSFS_Final-1/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:14<00:00,  1.42s/it]
#                    all        157        571      0.834      0.745      0.782      0.595
#        Ground_vehicles        157        103      0.846      0.589      0.622      0.502
# ...

# %% [markdown]
# ## FREEZING 10

# %% [markdown]
# REAL_F10(real_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL_F10/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:14<00:00,  1.59s/it]
#                    all        139        514      0.868      0.811      0.865      0.705
#        Ground_vehicles        139         88      0.881      0.795      0.846      0.766
#        Horizontal_sign        139        106      0.906      0.877      0.943      0.719
# ...

# %% [markdown]
# MSFS_F10(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/MSFS_F10/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:15<00:00,  1.56s/it]
#                    all        157        571      0.866      0.802      0.825      0.648
#        Ground_vehicles        157        103      0.871       0.66      0.714      0.611
#        Horizontal_sign        157         89      0.928      0.871      0.932      0.685
# ...

# %% [markdown]
# REAL_F10(msfs_test)

# %%
# !yolo task=detect mode=val model={ruta_drive}/REAL_F10/best.pt data=/content/MSFS_Final-1/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/MSFS_Final-1/test/labels.cache... 157 images, 19 backgrounds, 0 corrupt: 100% 157/157 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 521, len(boxes) = 571. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 10/10 [00:13<00:00,  1.34s/it]
#                    all        157        571      0.712       0.52      0.561       0.39
#        Ground_vehicles        157        103      0.724      0.126      0.195       0.16
#        Horizontal_sign        157         89      0.811      0.663      0.753      0.455
# ...

# %% [markdown]
# MSFS_F10(real_test)

# %%
# !yolo task=detect mode=val model={drive_maf}/MSFS_F10/best.pt data=/content/Real_Final-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68130309 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/Real_Final-2/test/labels.cache... 139 images, 11 backgrounds, 0 corrupt: 100% 139/139 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 496, len(boxes) = 514. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:12<00:00,  1.40s/it]
#                    all        139        514      0.662       0.55      0.589      0.414
#        Ground_vehicles        139         88       0.56      0.352      0.356      0.258
#        Horizontal_sign        139        106       0.78      0.736      0.827      0.569
# ...
